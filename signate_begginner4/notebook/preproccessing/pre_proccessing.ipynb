# %%
# Basic module
import numpy as np
import seaborn as sns
import pandas as pd
import pickle
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %% [markdown]
# -----------------
# #### ■データの読み込み
# ------------------

# %%
train = pd.read_csv('../1. data/train.csv')
test = pd.read_csv('../1. data/test.csv')

# %%
# 確認
train.head(1)
# Out:
#    id        mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   0  23.059782          6           140        110    2815     17.977429
#
#    model year  origin     car name
# 0          80       1  dodge aspen

# %%
# 統計情報確認
train.describe()
# Out:
#                id         mpg   cylinders  displacement      weight  \
# count  500.000000  500.000000  500.000000    500.000000   500.00000
# mean   500.176000   27.010940    5.192000    194.762000  2719.71400
# std    288.657179    7.356249    1.617519    106.277425   717.03541
# min      0.000000   15.787613    4.000000     79.000000  1755.00000
# 25%    242.250000   22.396641    4.000000    104.000000  2178.75000
# 50%    513.000000   26.228984    4.000000    140.000000  2615.00000
# 75%    750.250000   35.088333    6.000000    302.000000  3193.00000
# max    997.000000   44.763897    8.000000    429.000000  4732.00000
#
#        acceleration  model year      origin
# count    500.000000  500.000000  500.000000
# mean      15.300328   76.332000    1.420000
# std        2.261096    3.909007    0.759443
# min        9.530859   70.000000    1.000000
# 25%       13.441562   73.000000    1.000000
# 50%       15.231923   76.000000    1.000000
# 75%       17.190531   80.000000    2.000000
# max       21.922511   82.000000    3.000000

# %%
# 標準化関数
def stdsc(train, test):
    """学習データの値で標準化を行う関数
    
    Parameter:
    -----------------------------------
    train: ndarray
    test: ndarray
    
    Return:
    -----------------------------------
    ndarray
    """
    mean = np.mean(train)
    std = np.std(train)
    
    stdsc_test = (test - mean) / std
    
    return stdsc_test

# %%
# 標準化モジュールのインスタンス生成
# stdsc = StandardScaler()

# 標準化
train['cylinders_std'] = stdsc(train['cylinders'].values, train['cylinders'].values)
train['displacement_std'] = stdsc(train['displacement'].values, train['displacement'].values)
train['weight_std'] = stdsc(train['weight'].values, train['weight'].values)
train['acceleration_std'] = stdsc(train['acceleration'].values, train['acceleration'].values)
train['model year_std'] = stdsc(train['model year'].values, train['model year'].values)
train['origin_std'] = stdsc(train['origin'].values,train['origin'].values)

# %%
# 確認
columns = ['displacement_std','weight_std','acceleration_std','model year','origin_std']
for name in columns:
    print('{}: {}, {}'.format(name, train[name].mean(), train[name].var()))
# Out:
# displacement_std: 6.661338147750939e-18, 1.002004008016034
# weight_std: 1.9317880628477722e-17, 1.0020040080160313
# acceleration_std: -5.460493168740754e-16, 1.0020040080160324
# model year: 76.332, 15.280336673346628
# origin_std: 2.6645352591003758e-18, 1.0020040080160222

# %%
# テストデータの標準化
test.describe()
# Out:
#               id   cylinders  displacement       weight  acceleration  \
# count  500.00000  500.000000    500.000000   500.000000    500.000000
# mean   498.82400    5.148000    186.534000  2740.426000     15.301564
# std    289.26911    1.617197    103.173108   688.956869      2.222428
# min      1.00000    4.000000     80.000000  1613.000000      9.550639
# 25%    252.75000    4.000000    104.000000  2197.500000     13.467201
# 50%    490.00000    4.000000    140.000000  2702.000000     15.255378
# 75%    748.50000    6.000000    302.000000  3212.000000     17.182176
# max    999.00000    8.000000    429.000000  4732.000000     21.770354
#
#        model year      origin
# count   500.00000  500.000000
# mean     76.31600    1.448000
# std       3.83426    0.764503
# min      70.00000    1.000000
# 25%      73.00000    1.000000
# 50%      76.00000    1.000000
# 75%      80.00000    2.000000
# max      82.00000    3.000000

# %%
# テストデータの標準化
# 標準化
test['cylinders_std'] = stdsc(train['cylinders'].values, test['cylinders'].values)
test['displacement_std'] = stdsc(train['displacement'].values, test['displacement'].values)
test['weight_std'] = stdsc(train['weight'].values, test['weight'].values)
test['acceleration_std'] = stdsc(train['acceleration'].values, test['acceleration'].values)
test['model year_std'] = stdsc(train['model year'].values, test['model year'].values)
test['origin_std'] = stdsc(train['origin'].values,test['origin'].values)

# %%
# 確認
columns = ['displacement_std','weight_std','acceleration_std','model year','origin_std']
for name in columns:
    print('{}: {}, {}'.format(name, test[name].mean(), test[name].var()))
# Out:
# displacement_std: -0.07749755261528722, 0.9443227153240497
# weight_std: 0.028914531722199197, 0.9250651514741064
# acceleration_std: 0.0005471562542567172, 0.9680256182702732
# model year: 76.316, 14.701547094188372
# origin_std: 0.036906056197007216, 1.015401198505423

# %%
# 学習データの列取得
train.columns
# Out:
# Index(['id', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name', 'cylinders_std',
#        'displacement_std', 'weight_std', 'acceleration_std', 'model year_std',
#        'origin_std'],
#       dtype='object')

# %%
# テストデータの列取得
test.columns
# Out:
# Index(['id', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name', 'cylinders_std',
#        'displacement_std', 'weight_std', 'acceleration_std', 'model year_std',
#        'origin_std'],
#       dtype='object')

# %%
# 学習データ
# 不要な列を削除
drop_colums = [
        'id', 
#         'mpg', 
        'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'car name', 
#         'displacement_std', 'weight_std', 'acceleration_std', 'model year_std', 'cylinders_std', 'origin_std'
]

X = train.drop(drop_colums, axis=1)
file_name = '../1. data/train_pre_proccessing.pkl'
with open(file_name, 'wb') as fp:
    pickle.dump(X, fp)

# %%
X
# Out:
#            mpg  cylinders_std  displacement_std  weight_std  acceleration_std  \
# 0    23.059782       0.500031         -0.515790    0.133022          1.185170
# 1    17.674521       1.737730          1.462149    2.423904         -0.790582
# 2    17.136353       1.737730          1.010049    0.075785         -0.925440
# 3    22.664666       0.500031          1.933087   -0.739496         -0.046018
# 4    17.872018       1.737730          2.206231   -0.662714         -2.514097
# ..         ...            ...               ...         ...               ...
# 495  22.798447      -0.737669         -0.515790    0.160942         -0.806945
# 496  35.173640      -0.737669         -0.920797   -0.678070          0.992704
# 497  17.825448       1.737730          1.010049    0.075785         -0.054514
# 498  28.545147      -0.737669         -0.920797   -0.823257         -0.874637
# 499  36.011880      -0.737669         -0.920797   -0.585932          0.028348
#
#      model year_std  origin_std
# 0          0.939285   -0.553591
# 1         -1.109320   -0.553591
# 2          0.683210   -0.553591
# 3         -1.365395   -0.553591
# 4         -1.621471   -0.553591
# ..              ...         ...
# 495        1.451437   -0.553591
# 496        0.939285    2.082556
# 497       -0.085017   -0.553591
# 498       -1.621471   -0.553591
# 499       -1.365395   -0.553591
#
# [500 rows x 7 columns]

# %%
# テストデータ
# 不要な列を削除
drop_colums = [
        'id', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'model year', 'origin', 'car name', 
#         'displacement_std', 'weight_std', 'acceleration_std', 'cylinders_std', 'origin_std'
]

X = test.drop(drop_colums, axis=1)
file_name = '../1. data/test_pre_proccessing.pkl'
with open(file_name, 'wb') as fp:
    pickle.dump(X, fp)

# %%
X
# Out:
#      cylinders_std  displacement_std  weight_std  acceleration_std  \
# 0        -0.737669         -0.911378   -1.004741         -0.110913
# 1        -0.737669         -0.920797    0.000399          0.017197
# 2        -0.737669         -0.986728    0.121854          1.116183
# 3        -0.737669         -0.515790    0.121854         -0.672902
# 4        -0.737669         -0.694747    0.489009         -0.713380
# ..             ...               ...         ...               ...
# 495      -0.737669          0.284804    1.605831          0.033638
# 496      -0.737669         -0.515790    0.000399         -0.745289
# 497       1.737730          1.160749    0.075785         -0.897672
# 498      -0.737669         -0.986728    0.121854          1.103327
# 499      -0.737669         -0.986728   -0.739496          2.719648
#
#      model year_std  origin_std
# 0          1.195361   -0.553591
# 1          0.683210   -0.553591
# 2          0.171059   -0.553591
# 3          1.451437    0.764483
# 4         -0.853244    0.764483
# ..              ...         ...
# 495       -0.085017   -0.553591
# 496        1.451437   -0.553591
# 497       -0.341093   -0.553591
# 498        0.171059   -0.553591
# 499       -1.109320    0.764483
#
# [500 rows x 6 columns]
